# %% [markdown]
# # Train a NeuralNet Classifier to Link FEBRL People Data

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rachhouse/intro-to-data-linking/blob/linking-work/tutorial_notebooks/02_Link_FEBRL_Data_with_NN_Classifier.ipynb)

# %% [markdown]
# In this tutorial, we'll train a neural net classifier to score candidate pairs for linking, using supervised learning. We will use the same training dataset as the SimSum classification tutorial, as well as the same augmentation, blocking, and comparing functions. The functions have been included in a separate `.py` file for re-use and convenience, so we can focus on code unique to this tutorial.

# %%
import itertools

import altair as alt
import pandas as pd
import tensorflow as tf

from sklearn.model_selection import train_test_split

# %%
# Grab the linking functions file from github and save locally for Colab.
# We'll import our previously used linking functions from this file.
import linking_tutorial_functions as tutorial

# %% [markdown]
# ## Load Training Data and Ground Truth Labels

# %%
df_A, df_B, df_ground_truth = tutorial.load_febrl_training_data()

# %% [markdown]
# ## Data Augmentation

# %%
# %%time

for df in [df_A, df_B]:
    df = tutorial.augment_data(df)
# Out:
# CPU times: user 82.8 ms, sys: 3.38 ms, total: 86.1 ms
# Wall time: 84.9 ms

# %% [markdown]
# ## Blocking

# %%
full_blocker_pairs = df_A.shape[0] * df_B.shape[0]

candidate_links = tutorial.block(df_A, df_B)
blocked_pairs = candidate_links.shape[0]

search_space_reduction = round((1 - (blocked_pairs/full_blocker_pairs)) * 100, 2)

print(f"{blocked_pairs:,} pairs after blocking: {search_space_reduction}% search space reduction.")
# Out:
# 653,588 pairs after blocking: 97.39% search space reduction.

# %% [markdown]
# ## Comparing

# %%
# %%time

features = tutorial.compare(candidate_links, df_A, df_B)
# Out:
# CPU times: user 44.4 s, sys: 906 ms, total: 45.3 s
# Wall time: 45 s

# %%
features.head()
# Out:
#                                                                            soundex_surname  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82                0
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc                0
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5                0
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f                0
#                                      201c4dba-825a-42f2-b7a8-832b792af90b                0
#
#                                                                            soundex_firstname  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82                  1
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc                  1
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5                  1
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f                  1
#                                      201c4dba-825a-42f2-b7a8-832b792af90b                  0
#
#                                                                            nysiis_surname  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82               0
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc               0
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5               0
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f               0
#                                      201c4dba-825a-42f2-b7a8-832b792af90b               0
#
#                                                                            nysiis_firstname  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82                 1
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc                 1
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5                 1
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f                 1
#                                      201c4dba-825a-42f2-b7a8-832b792af90b                 0
#
#                                                                            last_name  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82   0.000000
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc   0.577778
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5   0.588889
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f   0.455556
#                                      201c4dba-825a-42f2-b7a8-832b792af90b   0.577778
#
#                                                                            first_name  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82    1.000000
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc    1.000000
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5    1.000000
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f    1.000000
#                                      201c4dba-825a-42f2-b7a8-832b792af90b    0.611111
#
#                                                                            address_1  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82   0.263158
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc   0.210526
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5   0.176471
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f   0.235294
#                                      201c4dba-825a-42f2-b7a8-832b792af90b   0.083333
#
#                                                                            address_2  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82   0.225806
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc   0.032258
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5   0.032258
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f   0.193548
#                                      201c4dba-825a-42f2-b7a8-832b792af90b   0.129032
#
#                                                                              suburb  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82  0.384615
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc  0.230769
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5  0.384615
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f  0.307692
#                                      201c4dba-825a-42f2-b7a8-832b792af90b  0.153846
#
#                                                                            postcode  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82       0.2
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc       0.4
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5       0.2
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f       0.2
#                                      201c4dba-825a-42f2-b7a8-832b792af90b       0.6
#
#                                                                            state  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82   0.25
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc   1.00
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5   0.25
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f   0.25
#                                      201c4dba-825a-42f2-b7a8-832b792af90b   0.25
#
#                                                                            date_of_birth  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82            0.0
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc            0.0
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5            0.0
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f            0.0
#                                      201c4dba-825a-42f2-b7a8-832b792af90b            0.0
#
#                                                                            phone_number  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82      0.333333
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc      0.333333
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5      0.333333
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f      0.083333
#                                      201c4dba-825a-42f2-b7a8-832b792af90b      0.416667
#
#                                                                                 ssn
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82  0.000000
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc  0.142857
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5  0.000000
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f  0.142857
#                                      201c4dba-825a-42f2-b7a8-832b792af90b  0.571429

# %% [markdown]
# ## Add Labels to Feature Vectors

# %%
df_ground_truth["ground_truth"] = df_ground_truth["ground_truth"].apply(lambda x: 1.0 if x else 0.0)

df_labeled_features = pd.merge(
    features,
    df_ground_truth,
    on=["person_id_A", "person_id_B"],
    how="left"
)

df_labeled_features["ground_truth"].fillna(0, inplace=True)
df_labeled_features.head()
# Out:
#                                                                            soundex_surname  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82                0
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc                0
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5                0
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f                0
#                                      201c4dba-825a-42f2-b7a8-832b792af90b                0
#
#                                                                            soundex_firstname  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82                  1
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc                  1
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5                  1
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f                  1
#                                      201c4dba-825a-42f2-b7a8-832b792af90b                  0
#
#                                                                            nysiis_surname  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82               0
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc               0
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5               0
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f               0
#                                      201c4dba-825a-42f2-b7a8-832b792af90b               0
#
#                                                                            nysiis_firstname  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82                 1
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc                 1
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5                 1
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f                 1
#                                      201c4dba-825a-42f2-b7a8-832b792af90b                 0
#
#                                                                            last_name  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82   0.000000
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc   0.577778
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5   0.588889
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f   0.455556
#                                      201c4dba-825a-42f2-b7a8-832b792af90b   0.577778
#
#                                                                            first_name  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82    1.000000
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc    1.000000
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5    1.000000
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f    1.000000
#                                      201c4dba-825a-42f2-b7a8-832b792af90b    0.611111
#
#                                                                            address_1  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82   0.263158
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc   0.210526
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5   0.176471
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f   0.235294
#                                      201c4dba-825a-42f2-b7a8-832b792af90b   0.083333
#
#                                                                            address_2  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82   0.225806
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc   0.032258
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5   0.032258
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f   0.193548
#                                      201c4dba-825a-42f2-b7a8-832b792af90b   0.129032
#
#                                                                              suburb  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82  0.384615
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc  0.230769
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5  0.384615
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f  0.307692
#                                      201c4dba-825a-42f2-b7a8-832b792af90b  0.153846
#
#                                                                            postcode  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82       0.2
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc       0.4
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5       0.2
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f       0.2
#                                      201c4dba-825a-42f2-b7a8-832b792af90b       0.6
#
#                                                                            state  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82   0.25
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc   1.00
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5   0.25
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f   0.25
#                                      201c4dba-825a-42f2-b7a8-832b792af90b   0.25
#
#                                                                            date_of_birth  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82            0.0
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc            0.0
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5            0.0
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f            0.0
#                                      201c4dba-825a-42f2-b7a8-832b792af90b            0.0
#
#                                                                            phone_number  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82      0.333333
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc      0.333333
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5      0.333333
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f      0.083333
#                                      201c4dba-825a-42f2-b7a8-832b792af90b      0.416667
#
#                                                                                 ssn  \
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82  0.000000
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc  0.142857
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5  0.000000
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f  0.142857
#                                      201c4dba-825a-42f2-b7a8-832b792af90b  0.571429
#
#                                                                            ground_truth
# person_id_A                          person_id_B
# 002cf4ec-57d0-4ebf-a31b-88db4441ff2e 061b9c3f-afbe-41e5-923b-3de29a4e5b82           0.0
#                                      081ec178-99a1-4895-b96e-7c03cf8bbfdc           0.0
#                                      17b274b5-aa3f-43cc-96ae-21283b7d1ca5           0.0
#                                      1f70d4cd-3106-4d15-af9f-1617a43ca83f           0.0
#                                      201c4dba-825a-42f2-b7a8-832b792af90b           0.0

# %% [markdown]
# ## Separate Candidate Links into Train/Test

# %%
X = df_labeled_features.drop("ground_truth", axis=1)
y = df_labeled_features["ground_truth"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=y, test_size=0.2
)

# %% [markdown]
# ## Train Neural Net Classifier

# %%
def create_nn_linking_classifier():
    """Return a simple NN classifier for to train on candidate links."""
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(16, activation="relu", input_shape=(14,)),
        tf.keras.layers.Dense(8, activation="relu"),
        tf.keras.layers.Dense(4, activation="relu"),        
        tf.keras.layers.Dense(1, activation="sigmoid")
    ])
    
    model.compile(
        optimizer="adam",
        loss="binary_crossentropy",
        metrics="accuracy"
    )
    
    return model

# %%
model = create_nn_linking_classifier()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 16)                240
# _________________________________________________________________
# dense_4 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 36
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 417
# Trainable params: 417
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=8)
# Out:
# Epoch 1/8
# 16340/16340 [==============================] - 9s 505us/step - loss: 0.0315 - accuracy: 0.9976
# Epoch 2/8
# 16340/16340 [==============================] - 8s 495us/step - loss: 1.4660e-05 - accuracy: 1.0000
# Epoch 3/8
# 16340/16340 [==============================] - 8s 501us/step - loss: 1.0944e-05 - accuracy: 1.0000
# Epoch 4/8
# 16340/16340 [==============================] - 8s 502us/step - loss: 3.3497e-05 - accuracy: 1.0000
# Epoch 5/8
# 16340/16340 [==============================] - 8s 505us/step - loss: 3.7372e-06 - accuracy: 1.0000
# Epoch 6/8
# 16340/16340 [==============================] - 8s 504us/step - loss: 2.2176e-05 - accuracy: 1.0000
# Epoch 7/8
# 16340/16340 [==============================] - 8s 500us/step - loss: 1.4301e-06 - accuracy: 1.0000
# Epoch 8/8
# 16340/16340 [==============================] - 8s 500us/step - loss: 8.4240e-07 - accuracy: 1.0000

# %% [markdown]
# ## Predict Using NN Classifier

# %%
y_pred = model.predict(X_test)

# %%
df_predictions = X_test.copy()
df_predictions["model_score"] = y_pred
df_predictions["ground_truth"] = y_test

# %% [markdown]
# ## Choosing a Linking Model Score Threshold

# %% [markdown]
# ### Model Score Distribution

# %%
tutorial.plot_model_score_distribution(df_predictions)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Precision and Recall vs. Model Score

# %%
blocking_eval, df_eval, df_top_links, df_bottom_links = tutorial.evaluate_linking(
    df=df_predictions,
    df_true_links=df_ground_truth,
    df_left=df_A,
    df_right=df_B,
)

# %%
tutorial.plot_precision_recall_vs_threshold(df_eval)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Top Scoring `k` Links

# %%
display_cols = [
    "first_name", "surname",
    "street_number", "address_1", "address_2", "suburb", "postcode", "state",
    "date_of_birth", "age", "phone_number", "soc_sec_id",
    "soundex_surname", "soundex_firstname",
    "nysiis_surname", "nysiis_firstname",
]

display_cols = [[f"{col}_x", f"{col}_y"] for col in display_cols]
display_cols = list(itertools.chain.from_iterable(display_cols))

# %%
with pd.option_context('display.max_columns', None):
    display(df_top_links[["person_id_A", "person_id_B", "model_score", "ground_truth"] + display_cols])
# Out:
#                             person_id_A                           person_id_B  \
# 0  5dddffa3-f575-4b5b-9e2f-240c2e615baf  494d290b-4772-44a0-a5bd-3536884d949d
# 1  bf36c20c-2695-4c29-8d34-13770bbd13f5  677dde0f-702b-4940-9d21-6f4db3a4a30e
# 2  96d624bd-1fec-46cb-b02e-1a25ff4147f9  12fe190f-1370-413b-aea0-e7099e985639
# 3  58226b7d-5c99-4e21-8d56-924459c250d8  143d9020-cf6b-4a8e-892f-6642791a8022
# 4  30f1b962-441a-41e2-82b0-723131ddf1c3  9f86b52a-09b8-4fa2-b059-cac534705345
# 5  019cb351-74f6-4659-9d20-5294af088d3f  fba31d33-5f34-4c07-b012-6874edbabc08
# 6  d0c7073d-e643-4c46-a3db-c2adddebbac8  dbe67ebf-d0b5-43a7-828c-7a2aca3ec566
# 7  74e6e146-e0b2-4059-9f5a-89b603b3e209  de98090c-78de-49bc-bb64-854fcdfad2db
# 8  7d78981b-da9a-456d-83c2-dfa8a842a786  d76c3859-1fb3-4e8d-8e21-8aa31bb80cdf
# 9  6200fe8c-49f9-4d89-9a98-c877dec5b778  a264bbe3-2bc0-4464-af35-2de52b4aebb5
#
#    model_score  ground_truth first_name_x first_name_y surname_x surname_y  \
# 0          1.0           1.0        james       jimmke    finlay    fimlau
# 1          1.0           1.0     samantha     samanyha  campbell  campbell
# 2          1.0           1.0        dylan         dyln   garnett   garnett
# 3          1.0           1.0        ryley        rlyry    garcia    garcia
# 4          1.0           1.0         liam         liam  mcgregor  mcgernor
# 5          1.0           1.0       alisha       rapson    rapson    aludha
# 6          1.0           1.0     rhiannon     rhiannon   navarro    navarr
# 7          1.0           1.0        tiana        tiana    corbin    corvin
# 8          1.0           1.0      aleisha      aleisha   kalnins    kalnns
# 9          1.0           1.0       jordan       jordan     maier    maiero
#
#   street_number_x street_number_y         address_1_x         address_1_y  \
# 0              16              16       cashion court       cashion court
# 1               8               2      allman circuit      allman circuit
# 2              36              36
# 3              73              73    blackbutt street    blackbutt street
# 4              27              27        kavel street        kavel street
# 5               1               1   callaway crescent   callaway crescent
# 6              14              14       carnall close        carnalwclose
# 7              16              16         zox circuit         zox circuit
# 8              14              13         fleay place         fleay plsce
# 9              44              44      shumack street      shumack street
#
#   address_2_x address_2_y          suburb_x          suburb_y postcode_x  \
# 0                           west wollongong   west wollongong       3012
# 1                                   boulder           bousder       4217
# 2                             mount torrens     mount torrens       3608
# 3                                 villawood         villawood       6148
# 4                                leppington        leppington       4883
# 5   merlewood   merlewood         currajong         currajong       2160
# 6                                     corio             corio       4873
# 7                              shellharbour      shellharbour       6066
# 8                                  murarrie           murarre       2655
# 9                 colbara            orange            oranfe       5070
#
#   postcode_y state_x state_y date_of_birth_x date_of_birth_y age_x age_y  \
# 0       3012      sa      sa        19620626        19620626
# 1       4217      sa      sa        19990907        19990907    10    10
# 2       3680     vic     vic        19760504        19706004    38    38
# 3       6148     nsw     nsw
# 4       4883     vic     vic        19861115        19861115
# 5       2160     tas     tas                                    28    28
# 6       4873     nsw     nsk
# 7       3088     qld     qld        19220206        19220206    31    13
# 8       2655     nsw     nsw        19540327        19540327
# 9       5070                        19771128        19717128     6     6
#
#   phone_number_x phone_number_y soc_sec_id_x soc_sec_id_y soundex_surname_x  \
# 0    08 41796533    08 41796533      2116699      2116699              F540
# 1    02 18386674    02 18386674      7950294      7950294              C514
# 2    07 05855936    07 05855936      8816524      8816524              G653
# 3    08 16002307    08 76334766      2136157      2136157              G620
# 4    08 43749772    08 43749772      7315231      4800278              M262
# 5    04 41588682    04 41588682      5026102      5026102              R125
# 6    02 94999881    02 94999881      1170321      1170321              N160
# 7    02 69598973    02 69538973      8178224      8178224              C615
# 8    08 42674904    08 42674904      8567884      8567884              K455
# 9    04 89787858    04 89787858      8916980      8916980              M600
#
#   soundex_surname_y soundex_firstname_x soundex_firstname_y nysiis_surname_x  \
# 0              F540                J520                J520            FANLY
# 1              C514                S553                S550          CANPBAL
# 2              G653                D450                D450           GARNAT
# 3              G620                R400                R460             GARC
# 4              M265                L500                L500         MCGRAGAR
# 5              A430                A420                R125           RAPSAN
# 6              N160                R550                R550            NAVAR
# 7              C615                T500                T500           CARBAN
# 8              K452                A420                A420           CALNAN
# 9              M600                J635                J635              MAR
#
#   nysiis_surname_y nysiis_firstname_x nysiis_firstname_y
# 0             FANL                JAN               JANC
# 1          CANPBAL             SANANT             SANANY
# 2           GARNAT              DYLAN               DYLN
# 3             GARC               RYLY              RLYRY
# 4         MCGARNAR                LAN                LAN
# 5             ALAD               ALAS             RAPSAN
# 6            NAVAR              RANAN              RANAN
# 7           CARVAN                TAN                TAN
# 8             CALN               ALAS               ALAS
# 9              MAR             JARDAN             JARDAN

# %% [markdown]
# ### Bottom Scoring `k` Links

# %%
with pd.option_context('display.max_columns', None):
    display(df_bottom_links[["person_id_A", "person_id_B", "model_score", "ground_truth"] + display_cols])
# Out:
#                             person_id_A                           person_id_B  \
# 0  fb114032-7f14-4efd-91c8-d3ca7cc56f25  76ffced6-c4ca-46de-a3fe-f8b164515bf5
# 1  f7ba245e-f13b-41da-968d-ad1db7b6de32  a34922f6-e96a-476c-9fd1-be582a8a2759
# 2  3e54266a-f481-442c-bc62-faae22053b37  f80c4b3e-5911-4f8e-b8e8-dae7aa841a5c
# 3  477db918-ca95-4c5f-a4b4-c655552151dd  2cc1490a-9567-4356-9b81-a479ec0d39ce
# 4  40d2c28c-eb73-4f75-abe6-f56d262a4ee3  52681cb9-4323-4703-97a9-503e934d09c5
# 5  96ea5263-823b-40a2-997c-01c17c9303b7  d112cf57-1d73-4f11-94bb-5faa7270698e
# 6  34b64f7d-a03a-41ea-a92a-843519337049  69f6e2ff-f3ea-41e7-ae1e-052b0a46ba2d
# 8  75e10765-371f-4fbe-b11c-83b898b3f399  69f6e2ff-f3ea-41e7-ae1e-052b0a46ba2d
# 7  31213616-f2a9-40f8-a269-dabe17490718  a31b3b72-f66f-4a63-9e01-2b303c2d94ac
# 9  d3514297-bbdc-469e-8f2d-29d3bf76fca4  488ba2fb-7b4e-4b88-bfaa-65f9d071c342
#
#     model_score  ground_truth first_name_x first_name_y surname_x  surname_y  \
# 0  4.669361e-17           0.0      madison        chloe   dugdale     wottro
# 1  4.698449e-17           0.0    katherine       jaspev   orzelek     fabbro
# 2  5.096307e-17           0.0     isabella          amy    burdin     leaver
# 3  5.151131e-17           0.0       jordan         jodl            blackewll
# 4  5.280433e-17           0.0       hayden       cameon     macha    bennwll
# 5  5.354776e-17           0.0       declen        jayde      kiss  tregoning
# 6  5.402933e-17           0.0       talyah      emalene     roche      lewal
# 8  6.524719e-17           0.0     courtney      emalene     white      lewal
# 7  5.416367e-17           0.0       hamish       joxhua     lette      prodw
# 9  6.591766e-17           0.0        kasey        calev      boss      weelr
#
#   street_number_x street_number_y        address_1_x      address_1_y  \
# 0               6              93                      perrin cidcuit
# 1              42             187    moorehead place
# 2              21              34   clemenger street
# 3              10              27       valder place
# 4              45              11       darby street    clement place
# 5              33              46      flecker place
# 6                              19   de graaff street
# 8              13              19       druitt place
# 7              63             173      mcphail place
# 9              14                      rennie street    vincent place
#
#     address_2_x       address_2_y            suburb_x      suburb_y  \
# 0   balena farm   st francis vlge   aspendale gardens
# 1                                             judbury   goonellabah
# 2                                            franklin    leichhxrdt
# 3                                            winmalee       kyabram
# 4       kinjibi                              thornlie     peakhurst
# 5                                         bonny hills     wahroonga
# 6                                          keiraville    burpengary
# 8                                        concord west    burpengary
# 7                                         scarborough     mona vale
# 9                                     wongaling beach
#
#   postcode_x postcode_y state_x state_y date_of_birth_x date_of_birth_y age_x  \
# 0       5065       2749     qld                                            34
# 1       3141       2680     vic      sa                                    29
# 2       6163       2221     vic     qld                                     9
# 3       5049       3977     qld     vif                                    29
# 4       3230       6157     nsw     nsw                                    37
# 5       5025       2130     qld     nsw                                    25
# 6       2281       2096     nsw     nsw                                    11
# 8       4051       2096     nsw     nsw                                     7
# 7       7015       2672     vic                                            35
# 9       2170       3226     vic     vic                                    20
#
#   age_y phone_number_x phone_number_y soc_sec_id_x soc_sec_id_y  \
# 0    32    08 51160660                     7482626      6611480
# 1    26    07 80406596                     6333363      1845086
# 2    37                   07 33436744      8243607      9831949
# 3    34                   03 82219196      5686855      2947694
# 4    35    07 11997647                     5882785      9241100
# 5    21                   08 71715612      9377051      2825385
# 6          03 87978274                     7416811      5838976
# 8          08 12732429                     2601647      5838976
# 7    29    03 65818771                     7655525      1978244
# 9    41                   04 63685334      2601961      5457685
#
#   soundex_surname_x soundex_surname_y soundex_firstname_x soundex_firstname_y  \
# 0              D234              W360                M325                C400
# 1              O624              F160                K365                J211
# 2              B635              L160                I214                A500
# 3                                B424                J635                J340
# 4              M200              B540                H350                C550
# 5              K200              T625                D245                J300
# 6              R200              L400                T400                E545
# 8              W300              L400                C635                E545
# 7              L300              P630                H520                J200
# 9              B200              W460                K200                C410
#
#   nysiis_surname_x nysiis_surname_y nysiis_firstname_x nysiis_firstname_y
# 0           DAGDAL             WATR            MADASAN                 CL
# 1          ORSALAC             FABR            CATARAN             JASPAF
# 2           BARDAN            LAVAR             ISABAL                ANY
# 3                           BLACAEL             JARDAN               JADL
# 4               MC            BANWL             HAYDAN              CANAN
# 5                C        TRAGANANG             DACLAN               JAYD
# 6              RAC            LAEAL               TALY             ENALAN
# 8              WAT            LAEAL             CARTNY             ENALAN
# 7              LAT            PRADW                HAN                JAX
# 9                B             WALR               CASY              CALAF
